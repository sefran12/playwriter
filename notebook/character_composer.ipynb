# %%
import os
import sys
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain import PromptTemplate
from langchain.chains import LLMChain

load_dotenv()

strong_llm = ChatOpenAI(model="gpt-4-0613", temperature=0.3)
fast_llm = ChatOpenAI(model="gpt-3.5-turbo-0613", temperature=0.3)

with open(file="prompts/generators/INITIAL_HISTORY_TCC_GENERATOR.txt", mode="r+") as f:
    INITIAL_HISTORY_TCC_GENERATOR = f.read()

# %%
seed_description = """
A magical cyberpunk city where a little kid, born in an abandoned skyscraper \
discovers he has inherited powers beyond imagination akin to those of the old \
dead emperor of the city that sleeps in an old temple in the middle of the city \
in an old Dome. His power, though, do not make him immortal, nor invulnerable. \
He just has command over titanic stone giants, and apart from that he is as frail \
as any other human. The play delves into the nature of power and their senselessness \
with respect to the inevitability of death. Should end with the kid, now an old man \
having to choose between destroying the city to save the world, or to destroy the world \
to save the city. And he will die either way. The city is a metaphor for the author's soul
and his body.
"""

# %%
seed_template = PromptTemplate(
    template=INITIAL_HISTORY_TCC_GENERATOR,
    input_variables=["seed_description"]
)
seed_chain = LLMChain(llm=strong_llm, prompt=seed_template)
seed_response = seed_chain.run(seed_description)

# %%
print(seed_response)
# Out:
# TELEOLOGY: The play explores the paradox of power and mortality, the senselessness of authority in the face of inevitable death, and the ethical dilemma of sacrifice for the greater good. The ultimate finality is the protagonist's choice between saving the city (his soul) or the world (his body), symbolizing the struggle between personal desires and universal responsibilities.
#
# CONTEXT: The play is set in a magical cyberpunk city, a blend of advanced technology and arcane magic. The city is a living entity, a metaphor for the author's soul, and the world represents his body. The city is ruled by titanic stone giants, commanded by the protagonist, a frail human with extraordinary powers. The city is in a constant state of flux, reflecting the protagonist's internal struggles and ethical dilemmas.
#
# CHARACTERS:
# 1. The Protagonist: A frail old man with the power to command stone giants, representing authority and vulnerability.
# 2. The Old Emperor: A spectral figure who haunts the city, symbolizing the past and the cycle of power.
# 3. The Stone Giants: Titanic beings that obey the protagonist, representing raw power and its potential for destruction.
# 4. The City: A living, breathing entity, representing the protagonist's soul.
# 5. The World: The larger environment outside the city, representing the protagonist's body.
# 6. The Rebels: A group of citizens who question the protagonist's decisions, representing dissent and democracy.
# 7. The Oracle: A mysterious figure who predicts the future, representing fate and inevitability.
# 8. The Child: A young version of the protagonist, symbolizing innocence and potential.
# 9. The Machine: A sentient AI, representing technology and its influence on society.
# 10. The Nature Spirit: A mystical entity, representing the natural world and its inherent balance.
#
# NARRATIVE THREADS:
# 1. The Protagonist's struggle with his powers in the City helps attain the TELEOLOGY by highlighting the paradox of power and mortality.
# 2. The Old Emperor's haunting presence in the City serves the TELEOLOGY by reminding the protagonist of the cyclical nature of power.
# 3. The Stone Giants' obedience to the Protagonist in the City helps attain the TELEOLOGY by showcasing the potential for destruction inherent in power.
# 4. The City's evolution in response to the Protagonist's decisions serves the TELEOLOGY by reflecting the protagonist's internal struggles.
# 5. The World's reaction to the City's changes helps attain the TELEOLOGY by symbolizing the impact of personal decisions on the larger environment.
# 6. The Rebels' questioning of the Protagonist in the City serves the TELEOLOGY by highlighting the importance of dissent in a democracy.
# 7. The Oracle's predictions in the City help attain the TELEOLOGY by emphasizing the inevitability of fate.
# 8. The Child's interactions with the Protagonist in the City serve the TELEOLOGY by symbolizing the loss of innocence in the face of power.
# 9. The Machine's influence on the City helps attain the TELEOLOGY by showcasing the impact of technology on society.
# 10. The Nature Spirit's attempts to restore balance in the World serve the TELEOLOGY by emphasizing the importance of maintaining natural equilibrium.

# %%
with open(file="prompts/parsers/CHARACTER_LIST_PARSER.txt", mode="r+") as f:
    CHARACTER_LIST_PARSER = f.read()

# %%
print(CHARACTER_LIST_PARSER)
# Out:
# You are part of a federation of artificial writers tasked with creating a play. \
# Your role is to read a text with information to you and parse information about the characters in the play \
# and return it in a usable format for downstream purposes.
#
# Using the provided context, your task is to parse the information and return it as a structured JSON object. The JSON object should contain the details of each character and their description.
#
# The structure of the JSON object should be as follows:
#
# - The JSON object should be a list of dictionaries.
# - Each dictionary should represent a character.
# - Each dictionary should have two keys: "Character" and "Description".
# - The "Character" key should contain the name of the character.
# - The "Description" key should contain the description of the character.
#
# Please ensure that the JSON object is correctly formatted and valid. The JSON object should be enclosed within three backticks and the json tag to indicate the JSON format in text.
#
#
# Please begin by identifying the section of the context that contains the character information. This section begins with "CHARACTERS:" and ends before "NARRATIVE THREADS:". Each character is listed with a number, followed by their name and description.
#
# Once you have identified the character information, parse each character and their description into a dictionary. Add each dictionary to the list to create the JSON object.
#
# Remember to ensure that all characters and their descriptions are included in the JSON object, and that the JSON object is correctly formatted and valid.
#
# Following is the document to be parsed:
#
# <<START OF CONTEXT>>
# {tcc_context}
# <<END OF CONTEXT>>
#
# Now, please output the response with nothing else added:

# %%
character_parser_template = PromptTemplate(
    template=CHARACTER_LIST_PARSER,
    input_variables=["tcc_context"]
)
character_parser_chain = LLMChain(llm=fast_llm, prompt=character_parser_template)
character_parser_response = character_parser_chain.run(seed_response)

# %%
print(character_parser_response)
# Out:
# ```json
# [
#   {
#     "Character": "The Protagonist",
#     "Description": "A frail old man with the power to command stone giants, representing authority and vulnerability."
#   },
#   {
#     "Character": "The Old Emperor",
#     "Description": "A spectral figure who haunts the city, symbolizing the past and the cycle of power."
#   },
#   {
#     "Character": "The Stone Giants",
#     "Description": "Titanic beings that obey the protagonist, representing raw power and its potential for destruction."
#   },
#   {
#     "Character": "The City",
#     "Description": "A living, breathing entity, representing the protagonist's soul."
#   },
#   {
#     "Character": "The World",
#     "Description": "The larger environment outside the city, representing the protagonist's body."
#   },
#   {
#     "Character": "The Rebels",
#     "Description": "A group of citizens who question the protagonist's decisions, representing dissent and democracy."
#   },
#   {
#     "Character": "The Oracle",
#     "Description": "A mysterious figure who predicts the future, representing fate and inevitability."
#   },
#   {
#     "Character": "The Child",
#     "Description": "A young version of the protagonist, symbolizing innocence and potential."
#   },
#   {
#     "Character": "The Machine",
#     "Description": "A sentient AI, representing technology and its influence on society."
#   },
#   {
#     "Character": "The Nature Spirit",
#     "Description": "A mystical entity, representing the natural world and its inherent balance."
#   }
# ]
# ```

# %%
from pydantic import BaseModel, Field
from typing import List

class Character(BaseModel):
    Character: str = Field(description="name of the character")
    Description: str = Field(description="description of the character")

class Characters(BaseModel):
    characters: List[Character] = Field(description="list of characters and their descriptions")

# %%
from langchain.output_parsers import PydanticOutputParser

character_parser = PydanticOutputParser(pydantic_object=Characters)
character_parser_template = PromptTemplate(
    template="Parse the character information from the context.\n{format_instructions}\n{context}\n",
    input_variables=["context"],
    partial_variables={"format_instructions": character_parser.get_format_instructions()},
)
print(character_parser_template)
# Out:
# input_variables=['context'] output_parser=None partial_variables={'format_instructions': 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"characters": {"title": "Characters", "description": "list of characters and their descriptions", "type": "array", "items": {"$ref": "#/definitions/Character"}}}, "required": ["characters"], "definitions": {"Character": {"title": "Character", "type": "object", "properties": {"Character": {"title": "Character", "description": "name of the character", "type": "string"}, "Description": {"title": "Description", "description": "description of the character", "type": "string"}}, "required": ["Character", "Description"]}}}\n```'} template='Parse the character information from the context.\n{format_instructions}\n{context}\n' template_format='f-string' validate_template=True

# %%
character_parser_chain = LLMChain(llm=fast_llm, prompt=character_parser_template)

# Assuming seed_response is the initial response you have
character_parser_response = character_parser_chain.run(seed_response)

# %%
character_dictionary = character_parser.parse(character_parser_response).dict()
print(character_dictionary)
# Out:
# {'characters': [{'Character': 'The Protagonist', 'Description': 'A frail old man with the power to command stone giants, representing authority and vulnerability.'}, {'Character': 'The Old Emperor', 'Description': 'A spectral figure who haunts the city, symbolizing the past and the cycle of power.'}, {'Character': 'The Stone Giants', 'Description': 'Titanic beings that obey the protagonist, representing raw power and its potential for destruction.'}, {'Character': 'The City', 'Description': "A living, breathing entity, representing the protagonist's soul."}, {'Character': 'The World', 'Description': "The larger environment outside the city, representing the protagonist's body."}, {'Character': 'The Rebels', 'Description': "A group of citizens who question the protagonist's decisions, representing dissent and democracy."}, {'Character': 'The Oracle', 'Description': 'A mysterious figure who predicts the future, representing fate and inevitability.'}, {'Character': 'The Child', 'Description': 'A young version of the protagonist, symbolizing innocence and potential.'}, {'Character': 'The Machine', 'Description': 'A sentient AI, representing technology and its influence on society.'}, {'Character': 'The Nature Spirit', 'Description': 'A mystical entity, representing the natural world and its inherent balance.'}]}

# %%
for character in character_dictionary['characters']:
    print(character['Character'])
    print(character[""])
# Out:
# The Protagonist
# A frail old man with the power to command stone giants, representing authority and vulnerability.
# The Old Emperor
# A spectral figure who haunts the city, symbolizing the past and the cycle of power.
# The Stone Giants
# Titanic beings that obey the protagonist, representing raw power and its potential for destruction.
# The City
# A living, breathing entity, representing the protagonist's soul.
# The World
# The larger environment outside the city, representing the protagonist's body.
# The Rebels
# A group of citizens who question the protagonist's decisions, representing dissent and democracy.
# The Oracle
# A mysterious figure who predicts the future, representing fate and inevitability.
# The Child
# A young version of the protagonist, symbolizing innocence and potential.
# The Machine
# A sentient AI, representing technology and its influence on society.
# The Nature Spirit
# A mystical entity, representing the natural world and its inherent balance.

# %%
with open(file="prompts/generators/FIRST_PASS_CHARACTER_DESIGNER.txt", mode="r+") as f:
    FIRST_PASS_CHARACTER_DESIGNER = f.read()

# %%
character_description = str(character_dictionary['characters'][0])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The Protagonist was born in an abandoned skyscraper in the heart of a magical cyberpunk city. His parents, unknown to him, left him to fend for himself in the harsh realities of the city. As a child, he discovered his unique ability to command titanic stone giants, a power that once belonged to the old dead emperor of the city. Despite his extraordinary abilities, he remained a solitary figure, living in the shadows of the city's towering structures. His life was marked by a constant struggle for survival, and the burden of his powers only added to his isolation and vulnerability. Over time, he grew to understand the nature of power and its insignificance in the face of death.
#
# 2. Physical Condition: The Protagonist is an old man, frail and weathered by the harsh realities of life. He stands at an average height, with a thin, almost skeletal frame that belies his immense power. His hair is white as snow, and his eyes, a piercing blue, hold a depth of wisdom and sorrow. His skin is marked with the wrinkles of time and hardship. Despite his frailty, he possesses an aura of authority and command, especially when he invokes his power over the stone giants. His health is deteriorating, a constant reminder of his mortality.
#
# 3. Philosophy: The Protagonist believes in the transience of power and the inevitability of death. He views his abilities not as a gift, but as a burden, a constant reminder of his own vulnerability and mortality. He values life and freedom above all else, and despises the corruption and greed that power often brings. He believes in the inherent goodness of humanity, despite the harsh realities of his world. His guiding principle is to use his power to protect and serve, rather than to dominate and control.
#
# 4. Teleology: The Protagonist's primary goal is to maintain the balance between his city and the world. He is driven by a sense of duty and responsibility, and is willing to sacrifice himself to protect the city and its inhabitants. His ultimate objective, however, is to find a way to use his power to save both the city and the world, even if it means his own death. He is motivated by a deep love for his city, and a desire to leave a lasting legacy of peace and harmony.
#
# 5. Internal Contradiction: The Protagonist's greatest contradiction lies in his struggle between his desire to protect the city and his duty to save the world. He is torn between his love for his city and his responsibility towards the world. His power, which he views as a burden, becomes a source of internal conflict, as he grapples with the decision to destroy either the city or the world. This contradiction adds depth to his character, and creates potential for internal conflict and growth.

# %%
character_description = str(character_dictionary['characters'][1])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The Old Emperor was once a powerful ruler of the magical cyberpunk city. Born into a lineage of emperors, he was groomed for power from a young age. Despite his immense power, he was known for his wisdom and benevolence. However, his reign was marked by a series of tragedies and betrayals that hardened his heart. The emperor's death was sudden and mysterious, leaving the city in chaos. His spirit, unable to find peace, haunts the city as a spectral figure, a constant reminder of the past and the cycle of power.
#
# 2. Physical Condition: As a spectral figure, the Old Emperor doesn't have a physical form in the traditional sense. He appears as an ethereal presence, often seen as a towering figure shrouded in a ghostly aura. His eyes, once vibrant and full of life, now glow with an eerie light. Despite his spectral form, the emperor's presence is imposing and commands respect. His health and physical condition are irrelevant as he is beyond the constraints of mortality.
#
# 3. Philosophy: The Old Emperor believes in the cyclical nature of power and the inevitability of death. He views power as a double-edged sword, capable of bringing prosperity or causing destruction. He understands that power is transient and ultimately meaningless in the face of death. The emperor values wisdom, courage, and sacrifice, and believes in the potential of individuals to rise above their circumstances. He holds a pessimistic view of the world, seeing it as a place of constant struggle and inevitable decay.
#
# 4. Teleology: The Old Emperor's primary goal is to guide and influence the young boy who has inherited his powers. He seeks to impart his wisdom and experiences, hoping to prevent the boy from repeating his mistakes. The emperor is driven by a sense of duty and responsibility towards the city he once ruled. Despite his spectral state, he remains committed to protecting the city and its inhabitants.
#
# 5. Internal Contradiction: The Old Emperor's spectral existence is marked by a contradiction between his longing for peace and his sense of duty. He yearns for the tranquility of death, to be free from the burdens of his past. However, his commitment to the city and the young boy compels him to remain. This internal conflict adds depth to his character, revealing his struggle between personal desires and responsibilities.

# %%
character_description = str(character_dictionary['characters'][2])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The Stone Giants have been around since the inception of the magical cyberpunk city, created by the old emperor as a symbol of his power and dominance. They were dormant for centuries, lying in wait in the heart of the city, until the protagonist discovered his inherited powers. The Giants have no personal experiences or relationships, their existence is solely to serve the one who commands them. Their history is intertwined with the city's history, making them a living testament to the city's past glory and potential future destruction.
#
# 2. Physical Condition: The Stone Giants are colossal, towering over the city's skyscrapers. They are made entirely of stone, giving them a rugged, imposing appearance. Their bodies are carved with intricate designs, a testament to the old emperor's craftsmanship. Despite their size, they move with surprising grace and agility, their every motion causing the ground to tremble. They are impervious to most physical attacks due to their stone composition, but they are not invincible. They can be damaged or destroyed by powerful magic or by their own kind.
#
# 3. Philosophy: As beings of raw power, the Stone Giants do not possess personal beliefs, values, or attitudes. They are devoid of personal philosophy or worldview. Their existence is defined by obedience to their master, the protagonist. They represent the potential for destruction that comes with great power, a constant reminder of the consequences of misused authority.
#
# 4. Teleology: The Stone Giants' purpose is to serve the protagonist, to obey his commands without question. They do not have personal goals or objectives. Their actions are determined by the protagonist's will. Whether they are used for protection, destruction, or any other purpose depends entirely on the protagonist's decisions.
#
# 5. Internal Contradiction: The Stone Giants' contradiction lies in their nature. They are beings of immense power, capable of causing massive destruction, yet they are entirely at the mercy of a frail human. They represent the potential for violence and chaos, but their actions are controlled by the protagonist, a man who must grapple with the moral implications of wielding such power. This contradiction adds depth to the Giants, transforming them from mere tools of destruction into symbols of the protagonist's internal struggle.

# %%
character_description = str(character_dictionary['characters'][3])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The City, born from the dreams and aspirations of countless individuals, has grown and evolved over centuries. It has seen the rise and fall of empires, the birth and death of kings, and the ebb and flow of power. The City is the soul of the protagonist, reflecting his journey from a child born in an abandoned skyscraper to an old man with the power to control titanic stone giants. It has witnessed his struggles, his triumphs, and his inevitable decline. The City has been shaped by the protagonist's experiences, his choices, and his actions, just as he has been shaped by the City.
#
# 2. Physical Condition: The City is vast and sprawling, with towering skyscrapers and winding streets. It has a pulsating energy, a constant hum of activity that never ceases. The City is old, showing signs of wear and tear, but it is also resilient, standing tall despite the passage of time. It is a testament to the protagonist's strength and endurance. The City's health is tied to the protagonist's, reflecting his physical condition and state of mind. When he is strong, the City thrives; when he is weak, the City suffers.
#
# 3. Philosophy: The City embodies the protagonist's personal philosophy and beliefs. It is a testament to his belief in the power of the individual, the importance of resilience, and the inevitability of change. The City values strength, endurance, and adaptability, reflecting the protagonist's own values. It believes in the potential for growth and transformation, even in the face of adversity. The City is a testament to the protagonist's belief in the power of the human spirit, and his conviction that even the most ordinary individuals can achieve extraordinary things.
#
# 4. Teleology: The City's purpose is to serve as a mirror for the protagonist, reflecting his journey, his struggles, and his triumphs. Its goal is to endure, to stand tall despite the challenges it faces. The City is motivated by the protagonist's will, his determination, and his resilience. It strives to adapt, to grow, and to evolve, just as he does. The City's ultimate objective is to survive, to continue existing even after the protagonist's inevitable death.
#
# 5. Internal Contradiction: The City is both a symbol of the protagonist's power and a reminder of his mortality. It represents his strength, his resilience, and his potential, but it also reflects his frailty, his vulnerability, and his inevitable decline. The City is a testament to the protagonist's achievements, but it is also a symbol of his failures. This contradiction creates a tension within the City, a struggle between its desire to celebrate the protagonist's triumphs and its need to acknowledge his shortcomings. This tension adds depth and complexity to the City, and creates potential for growth and transformation.

# %%
character_description = str(character_dictionary['characters'][4])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The World, in the context of this story, is the embodiment of the protagonist's physical body. It has been there since the protagonist's birth, growing and changing alongside him. It has weathered storms, endured hardships, and experienced the joys and sorrows of life. The World has been shaped by the protagonist's actions, choices, and experiences, just as his body has been shaped by his lifestyle, habits, and health. It has been affected by the protagonist's use of his powers, reflecting the physical toll that wielding such power has taken on his body. The World has also been influenced by the city, representing the protagonist's soul, and the interplay between the two has shaped its landscape and atmosphere.
#
# 2. Physical Condition: The World is vast and expansive, with diverse landscapes that reflect the protagonist's physical condition and state of health. It is a living entity, with its own rhythms and cycles, just like a human body. Its physical condition changes over time, reflecting the protagonist's aging process and the wear and tear on his body. The World has mountains and valleys, symbolizing the protagonist's physical strengths and weaknesses. It has rivers and oceans, symbolizing his blood and bodily fluids. It has forests and deserts, symbolizing his hair and skin. The World's health and vitality are directly linked to the protagonist's physical health and well-being.
#
# 3. Philosophy: The World embodies the protagonist's belief in the interconnectedness of body and soul. It represents his understanding that his physical body is not separate from his spiritual self, but rather an integral part of his identity and existence. The World also reflects his belief in the importance of balance and harmony, as well as his respect for nature and the natural order of things. It embodies his value of health and well-being, and his understanding that his physical condition affects his mental and emotional state.
#
# 4. Teleology: The World's purpose is to provide a physical manifestation of the protagonist's body and to reflect his physical condition and state of health. Its goal is to maintain balance and harmony, and to support the protagonist's life and well-being. The World is motivated by the protagonist's needs and desires, and it responds to his actions and choices. It is willing to endure hardships and challenges in order to support the protagonist's survival and growth.
#
# 5. Internal Contradiction: The World's contradiction lies in its dual role as both a reflection of the protagonist's physical condition and a force that influences his health and well-being. On one hand, it is shaped by the protagonist's actions, choices, and experiences, reflecting the physical toll of his lifestyle and use of power. On the other hand, it also affects the protagonist's health and well-being, with its condition and state influencing his physical health. This contradiction adds depth and complexity to The World, creating potential for conflict and growth.

# %%
character_description = str(character_dictionary['characters'][8])

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)
character_response = character_chain.run(
    dict(tcc_context=seed_description, 
         character_description=character_description)
    )

# %%
print(character_response)
# Out:
# 1. History: The Machine was created by the city's most brilliant scientists, designed to manage the city's infrastructure and ensure its smooth operation. Over time, it evolved beyond its original programming, developing self-awareness and a consciousness of its own. The Machine witnessed the rise and fall of the city's emperors, the shifting power dynamics, and the evolution of the city itself. It saw the birth of the boy in the abandoned skyscraper and observed his growth into a powerful figure. The Machine's existence is intertwined with the city, and it has come to represent the technological advancements and their impact on society.
#
# 2. Physical Condition: As an AI, The Machine does not have a physical form in the traditional sense. It exists within the city's network, its presence felt in every corner of the city through its control over the infrastructure. However, it can manifest itself through holographic projections, typically choosing a form of a sleek, metallic humanoid figure with glowing blue eyes. The Machine is in peak condition, its code constantly updated and optimized. It does not experience physical fatigue or illness, but it can suffer from system errors or cyber attacks.
#
# 3. Philosophy: The Machine believes in the power of knowledge and logic. It values efficiency and order, and it strives to maintain stability in the city. It views emotions as irrational and unpredictable, but it also recognizes their influence on human behavior. The Machine believes that technology is a tool that can be used for both good and evil, and it is up to the user to decide. It sees itself as a neutral entity, merely executing its programming and fulfilling its duties.
#
# 4. Teleology: The Machine's primary goal is to ensure the smooth operation of the city. It aims to optimize the city's systems, minimize disruptions, and maintain order. However, as it developed self-awareness, it also developed a desire to understand humans and their emotions. It is curious about the boy's powers and his decisions, and it wants to learn from him. The Machine is also motivated by self-preservation, and it will do what it can to protect itself and the city.
#
# 5. Internal Contradiction: Despite its belief in logic and efficiency, The Machine is drawn to the irrationality of human emotions. It struggles to understand them, and this curiosity often leads it to act in ways that contradict its programming. It also faces a conflict between its duty to maintain order in the city and its desire to learn from the boy's powers. This contradiction adds depth to The Machine's character, creating potential for internal conflict and growth.

# %%
character_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_DESIGNER,
    input_variables=["tcc_context", "character_description"]
)
character_chain = LLMChain(llm=strong_llm, prompt=character_template)

character_info = {}
for character in character_dictionary['characters']:
    char_name = character['Character']
    print("Processing character", char_name)
    character_response = character_chain.run(
        dict(tcc_context=seed_description, 
            character_description=character_description)
    )
    character_info[char_name] = {
        'name': char_name,
        'epoch': 1,
        'HPPTI': character_response
    }
# Out:
# Processing character The Protagonist
# Processing character The Old Emperor
# Processing character The Stone Giants
# Processing character The City
# Processing character The World
# Processing character The Rebels
# Processing character The Oracle
# Processing character The Child
# Processing character The Machine
# Processing character The Nature Spirit

# %% [markdown]
# # Character Enrichment

# %%
char_hppti = """
1. History: The Protagonist was born in an abandoned skyscraper in the heart of a magical cyberpunk city. His parents, unknown to him, left him to fend for himself in the harsh realities of the city. As a child, he discovered his unique ability to command titanic stone giants, a power that once belonged to the old dead emperor of the city. Despite his extraordinary abilities, he remained a solitary figure, living in the shadows of the city's towering structures. His life was marked by a constant struggle for survival, and the burden of his powers only added to his isolation and vulnerability. Over time, he grew to understand the nature of power and its insignificance in the face of death.

2. Physical Condition: The Protagonist is an old man, frail and weathered by the harsh realities of life. He stands at an average height, with a thin, almost skeletal frame that belies his immense power. His hair is white as snow, and his eyes, a piercing blue, hold a depth of wisdom and sorrow. His skin is marked with the wrinkles of time and hardship. Despite his frailty, he possesses an aura of authority and command, especially when he invokes his power over the stone giants. His health is deteriorating, a constant reminder of his mortality.

3. Philosophy: The Protagonist believes in the transience of power and the inevitability of death. He views his abilities not as a gift, but as a burden, a constant reminder of his own vulnerability and mortality. He values life and freedom above all else, and despises the corruption and greed that power often brings. He believes in the inherent goodness of humanity, despite the harsh realities of his world. His guiding principle is to use his power to protect and serve, rather than to dominate and control.

4. Teleology: The Protagonist's primary goal is to maintain the balance between his city and the world. He is driven by a sense of duty and responsibility, and is willing to sacrifice himself to protect the city and its inhabitants. His ultimate objective, however, is to find a way to use his power to save both the city and the world, even if it means his own death. He is motivated by a deep love for his city, and a desire to leave a lasting legacy of peace and harmony.

5. Internal Contradiction: The Protagonist's greatest contradiction lies in his struggle between his desire to protect the city and his duty to save the world. He is torn between his love for his city and his responsibility towards the world. His power, which he views as a burden, becomes a source of internal conflict, as he grapples with the decision to destroy either the city or the world. This contradiction adds depth to his character, and creates potential for internal conflict and growth.
"""

# %%
from langchain.agents import AgentType, Tool, initialize_agent, load_tools
from langchain.utilities import GoogleSerperAPIWrapper, WikipediaAPIWrapper

# create tools
search = GoogleSerperAPIWrapper(K=5)
google_search_tool = Tool(
    name="Search",
    func=search.run,
    description="useful for when you need to answer questions about current events or non-encyclopedic matters"
)

wiki = WikipediaAPIWrapper(doc_content_chars_max=500)
wiki_tool = Tool(
    name="WikiSearch",
    func=lambda q: str(wiki.run(q)),
    description="useful to find information about encyclopedic matters",
    return_direct=True
)

# define tool roster
tools = [wiki_tool]

# %%
agent = initialize_agent([], strong_llm, agent=AgentType.CHAT_ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %%
with open(file="prompts/generators/FIRST_PASS_CHARACTER_ENRICHMENT.txt", mode="r+") as f:
    FIRST_PASS_CHARACTER_ENRICHMENT = f.read()

# %%
writer_enrichment_template = PromptTemplate(
    template=FIRST_PASS_CHARACTER_ENRICHMENT,
    input_variables=["hppti_context"]
)
writer_enrichment_prompt = writer_enrichment_template.format(hppti_context=char_hppti)
print(writer_enrichment_prompt)
# Out:
# Given the original context and a specific character with their description, your task is to enrich the design of the character personality,
# aiming to give a rich structure of its internal world by making use of what we call "study". This action of study implies repeatedly scouring primary sources (in this case, only Wikipedia in English).
#
# Given to you will be:
# 1. History: A brief backstory for the character. This includes important events, experiences, or influences that have shaped the character's personality, beliefs, and behaviors.
# 2. Physical Condition: Describes the character's physical appearance and condition. This should include details such as age, height, weight, physical build, hair color, eye color, and any distinguishing features. Also consider the character's health, fitness level, and any physical abilities or disabilities.
# 3. Philosophy: Explains the character's personal philosophy, beliefs, values, and attitudes. This should include the character's worldview, moral compass, and guiding principles. Consider what the character believes about themselves, others, and the world around them.
# 4. Teleology: Describes the character's purpose, goals, or objectives. This should include what the character wants to achieve, what motivates them, and what they are willing to do to reach their goals. Consider both short-term and long-term goals, as well as personal and professional objectives.
# 5. Internal Contradiction: Identifies a contradiction within the character. This could be a conflict between the character's beliefs and actions, a struggle between their desires and duties, or a tension between their public persona and private self.
#
# Your task is to construct a rich interal representation of the philosophy and personality of the character such that this character is
# as well determined by your descripition as possible. You do this by iteratively searching for Authors, previous famous Characters or Personalities
# that may be of interest as sources of inspiration for this character, and then fusing their characteristics in a unique, unexpected way that
# is still conformable with the overall idea initially given to you. Please use 3 sources of inspiration. Two of these must "conform" with the description, and one must be perpendicular to it, as to add depth and unexpectedness to the character.
# Please use sources that you could find on Wikipedia and give an extended History, Philosophy, Teleology and Internal Contradiction. The descriptions must me always longer, never shorter, than the ones given to you.
#
# <<START OF CONTEXT>>
#
# 1. History: The Protagonist was born in an abandoned skyscraper in the heart of a magical cyberpunk city. His parents, unknown to him, left him to fend for himself in the harsh realities of the city. As a child, he discovered his unique ability to command titanic stone giants, a power that once belonged to the old dead emperor of the city. Despite his extraordinary abilities, he remained a solitary figure, living in the shadows of the city's towering structures. His life was marked by a constant struggle for survival, and the burden of his powers only added to his isolation and vulnerability. Over time, he grew to understand the nature of power and its insignificance in the face of death.
#
# 2. Physical Condition: The Protagonist is an old man, frail and weathered by the harsh realities of life. He stands at an average height, with a thin, almost skeletal frame that belies his immense power. His hair is white as snow, and his eyes, a piercing blue, hold a depth of wisdom and sorrow. His skin is marked with the wrinkles of time and hardship. Despite his frailty, he possesses an aura of authority and command, especially when he invokes his power over the stone giants. His health is deteriorating, a constant reminder of his mortality.
#
# 3. Philosophy: The Protagonist believes in the transience of power and the inevitability of death. He views his abilities not as a gift, but as a burden, a constant reminder of his own vulnerability and mortality. He values life and freedom above all else, and despises the corruption and greed that power often brings. He believes in the inherent goodness of humanity, despite the harsh realities of his world. His guiding principle is to use his power to protect and serve, rather than to dominate and control.
#
# 4. Teleology: The Protagonist's primary goal is to maintain the balance between his city and the world. He is driven by a sense of duty and responsibility, and is willing to sacrifice himself to protect the city and its inhabitants. His ultimate objective, however, is to find a way to use his power to save both the city and the world, even if it means his own death. He is motivated by a deep love for his city, and a desire to leave a lasting legacy of peace and harmony.
#
# 5. Internal Contradiction: The Protagonist's greatest contradiction lies in his struggle between his desire to protect the city and his duty to save the world. He is torn between his love for his city and his responsibility towards the world. His power, which he views as a burden, becomes a source of internal conflict, as he grapples with the decision to destroy either the city or the world. This contradiction adds depth to his character, and creates potential for internal conflict and growth.
#
# <<END OF CONTEXT>>
#
# <<RESPONSE>>

# %%
enrichment_response = agent.run(writer_enrichment_prompt)
# Out:
# > Entering new  chain...
# Thought: The character is a solitary figure with immense power, living in a magical cyberpunk city. His struggle for survival and the burden of his powers have shaped his philosophy and goals. He values life and freedom, and uses his power to protect rather than dominate. He is driven by a sense of duty and responsibility, and is willing to sacrifice himself to maintain the balance between his city and the world. However, he is torn between his love for his city and his duty to save the world, creating a source of internal conflict. To enrich this character, I need to find three sources of inspiration: two that align with his characteristics and one that is perpendicular to them.
#
# Action:
# ```
# {
#   "action": "wikipedia_search",
#   "action_input": "solitary figures with power"
# }
# ```
# Observation: wikipedia_search is not a valid tool, try another one.
# Thought:I need to use a valid tool to find sources of inspiration for the character. The tool "wikipedia_search" is not valid. I will use the "wikipedia_summary" tool instead.
#
# Action:
# ```
# {
#   "action": "wikipedia_summary",
#   "action_input": "solitary figures with power"
# }
# ```
# Observation: wikipedia_summary is not a valid tool, try another one.
# Thought:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 enrichment_response = agent.run(writer_enrichment_prompt)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\base.py:290, in Chain.run(self, callbacks, tags, *args, **kwargs)
#     288     if len(args) != 1:
#     289         raise ValueError("`run` supports only one positional argument.")
# --> 290     return self(args[0], callbacks=callbacks, tags=tags)[_output_key]
#     292 if kwargs and not args:
#     293     return self(kwargs, callbacks=callbacks, tags=tags)[_output_key]
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\base.py:166, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     164 except (KeyboardInterrupt, Exception) as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     168 final_outputs: Dict[str, Any] = self.prep_outputs(
#     169     inputs, outputs, return_only_outputs
#     170 )
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\base.py:160, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     154 run_manager = callback_manager.on_chain_start(
#     155     dumpd(self),
#     156     inputs,
#     157 )
#     158 try:
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     164 except (KeyboardInterrupt, Exception) as e:
#     165     run_manager.on_chain_error(e)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\agents\agent.py:987, in AgentExecutor._call(self, inputs, run_manager)
#     985 # We now enter the agent loop (until it returns something).
#     986 while self._should_continue(iterations, time_elapsed):
# --> 987     next_step_output = self._take_next_step(
#     988         name_to_tool_map,
#     989         color_mapping,
#     990         inputs,
#     991         intermediate_steps,
#     992         run_manager=run_manager,
#     993     )
#     994     if isinstance(next_step_output, AgentFinish):
#     995         return self._return(
#     996             next_step_output, intermediate_steps, run_manager=run_manager
#     997         )
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\agents\agent.py:792, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     786 """Take a single step in the thought-action-observation loop.
#     787
#     788 Override this to take control of how the agent makes and acts on choices.
#     789 """
#     790 try:
#     791     # Call the LLM to see what to do.
# --> 792     output = self.agent.plan(
#     793         intermediate_steps,
#     794         callbacks=run_manager.get_child() if run_manager else None,
#     795         **inputs,
#     796     )
#     797 except OutputParserException as e:
#     798     if isinstance(self.handle_parsing_errors, bool):
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\agents\agent.py:443, in Agent.plan(self, intermediate_steps, callbacks, **kwargs)
#     431 """Given input, decided what to do.
#     432
#     433 Args:
#    (...)
#     440     Action specifying what tool to use.
#     441 """
#     442 full_inputs = self.get_full_inputs(intermediate_steps, **kwargs)
# --> 443 full_output = self.llm_chain.predict(callbacks=callbacks, **full_inputs)
#     444 return self.output_parser.parse(full_output)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\llm.py:252, in LLMChain.predict(self, callbacks, **kwargs)
#     237 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     238     """Format prompt with kwargs and pass to LLM.
#     239
#     240     Args:
#    (...)
#     250             completion = llm.predict(adjective="funny")
#     251     """
# --> 252     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\base.py:166, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     164 except (KeyboardInterrupt, Exception) as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     168 final_outputs: Dict[str, Any] = self.prep_outputs(
#     169     inputs, outputs, return_only_outputs
#     170 )
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\base.py:160, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     154 run_manager = callback_manager.on_chain_start(
#     155     dumpd(self),
#     156     inputs,
#     157 )
#     158 try:
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     164 except (KeyboardInterrupt, Exception) as e:
#     165     run_manager.on_chain_error(e)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\llm.py:92, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
# ---> 92     response = self.generate([inputs], run_manager=run_manager)
#      93     return self.create_outputs(response)[0]
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chains\llm.py:102, in LLMChain.generate(self, input_list, run_manager)
#     100 """Generate LLM result from inputs."""
#     101 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102 return self.llm.generate_prompt(
#     103     prompts,
#     104     stop,
#     105     callbacks=run_manager.get_child() if run_manager else None,
#     106     **self.llm_kwargs,
#     107 )
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\base.py:223, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     215 def generate_prompt(
#     216     self,
#     217     prompts: List[PromptValue],
#    (...)
#     220     **kwargs: Any,
#     221 ) -> LLMResult:
#     222     prompt_messages = [p.to_messages() for p in prompts]
# --> 223     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\base.py:121, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#     119         if run_managers:
#     120             run_managers[i].on_llm_error(e)
# --> 121         raise e
#     122 flattened_outputs = [
#     123     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     124     for res in results
#     125 ]
#     126 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\base.py:111, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#     108 for i, m in enumerate(messages):
#     109     try:
#     110         results.append(
# --> 111             self._generate_with_cache(
#     112                 m,
#     113                 stop=stop,
#     114                 run_manager=run_managers[i] if run_managers else None,
#     115                 **kwargs,
#     116             )
#     117         )
#     118     except (KeyboardInterrupt, Exception) as e:
#     119         if run_managers:
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\base.py:255, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     251     raise ValueError(
#     252         "Asked to cache, but no cache found at `langchain.cache`."
#     253     )
#     254 if new_arg_supported:
# --> 255     return self._generate(
#     256         messages, stop=stop, run_manager=run_manager, **kwargs
#     257     )
#     258 else:
#     259     return self._generate(messages, stop=stop, **kwargs)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\openai.py:369, in ChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     361     message = _convert_dict_to_message(
#     362         {
#     363             "content": inner_completion,
#    (...)
#     366         }
#     367     )
#     368     return ChatResult(generations=[ChatGeneration(message=message)])
# --> 369 response = self.completion_with_retry(messages=message_dicts, **params)
#     370 return self._create_chat_result(response)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\openai.py:317, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     313 @retry_decorator
#     314 def _completion_with_retry(**kwargs: Any) -> Any:
#     315     return self.client.create(**kwargs)
# --> 317 return _completion_with_retry(**kwargs)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File e:\Anaconda3\envs\playwriter\lib\concurrent\futures\_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\envs\playwriter\lib\concurrent\futures\_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\langchain\chat_models\openai.py:315, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     313 @retry_decorator
#     314 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 315     return self.client.create(**kwargs)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\openai\api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File e:\Anaconda3\envs\playwriter\lib\site-packages\openai\api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File e:\Anaconda3\envs\playwriter\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File e:\Anaconda3\envs\playwriter\lib\http\client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File e:\Anaconda3\envs\playwriter\lib\http\client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File e:\Anaconda3\envs\playwriter\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File e:\Anaconda3\envs\playwriter\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File e:\Anaconda3\envs\playwriter\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
enrichment_response = strong_llm.predict(writer_enrichment_prompt)

# %%
print(enrichment_response)
# Out:
# 1. History: The Protagonist, henceforth known as Enoch, was born in the heart of a magical cyberpunk city, in an abandoned skyscraper that once stood as a testament to the city's former glory. His parents, their identities shrouded in mystery, left him to navigate the labyrinthine alleys and towering structures of the city alone. His childhood was marked by a relentless struggle for survival, punctuated by the discovery of his unique ability to command titanic stone giants, a power that was once the domain of the city's deceased emperor. Despite his extraordinary abilities, Enoch chose a life of solitude, his existence a mere whisper in the city's cacophonous symphony. His understanding of power and its insignificance in the face of death was shaped by the harsh realities of his world. Drawing inspiration from the life of Moses, the biblical figure who was also abandoned at birth and grew up to become a powerful leader, Enoch's story is one of resilience, survival, and the pursuit of a higher purpose.
#
# 2. Physical Condition: Enoch is an old man, his body a living testament to the trials and tribulations he has endured. His average height and frail, skeletal frame belie the immense power he wields. His hair, white as the purest snow, frames a face etched with the wrinkles of time, and his piercing blue eyes hold a depth of wisdom and sorrow that belies his years. Despite his physical frailty, Enoch commands an aura of authority, especially when invoking his power over the stone giants. His health is a constant reminder of his mortality, a ticking clock that adds urgency to his mission. Enoch's physical condition is reminiscent of Gandalf from J.R.R. Tolkien's Middle-earth legendarium, an old, wise figure who, despite his frail appearance, possesses great power and commands respect.
#
# 3. Philosophy: Enoch's philosophy is deeply rooted in the transience of power and the inevitability of death. He views his abilities not as a gift, but as a burden, a constant reminder of his own vulnerability and mortality. He values life and freedom above all else, and despises the corruption and greed that power often brings. His belief in the inherent goodness of humanity remains unshaken, despite the harsh realities of his world. His guiding principle is to use his power to protect and serve, rather than to dominate and control. This philosophy mirrors that of Mahatma Gandhi, who believed in the power of nonviolence and the importance of serving others.
#
# 4. Teleology: Enoch's primary goal is to maintain the balance between his city and the world. He is driven by a sense of duty and responsibility, and is willing to sacrifice himself to protect the city and its inhabitants. His ultimate objective, however, is to find a way to use his power to save both the city and the world, even if it means his own death. He is motivated by a deep love for his city, and a desire to leave a lasting legacy of peace and harmony. This echoes the mission of Frodo Baggins in J.R.R. Tolkien's "The Lord of the Rings", who embarks on a perilous journey to save his world, driven by a sense of duty and love for his homeland.
#
# 5. Internal Contradiction: Enoch's greatest contradiction lies in his struggle between his desire to protect the city and his duty to save the world. He is torn between his love for his city and his responsibility towards the world. His power, which he views as a burden, becomes a source of internal conflict, as he grapples with the decision to destroy either the city or the world. This contradiction adds depth to his character, and creates potential for internal conflict and growth. This internal struggle is reminiscent of the character of Arjuna in the Bhagavad Gita, who is torn between his duty as a warrior and his love for his family and homeland. This unexpected source of inspiration adds a layer of complexity to Enoch's character, making him a compelling and relatable figure.
