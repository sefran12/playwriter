# %%
import os
import sys
from dotenv import load_dotenv
from typing import Dict, List, Optional
from langchain import PromptTemplate
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationSummaryBufferMemory, ConversationBufferWindowMemory
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel
from langchain.chat_models import ChatOpenAI

load_dotenv()

strong_llm = ChatOpenAI(model="gpt-4", temperature=0.2)
fast_llm = ChatOpenAI(model="gpt-3.5-turbo-16k", temperature=0.2)

class Character(BaseModel):
    internal_state: str = None
    ambitions: str = None
    teleology: str = None
    philosophy: str = None
    physical_state: str = None
    long_term_memory: List[str] = []
    short_term_memory: List[str] = []
    internal_contradictions: List[str] = []


class CharacterGeneration:
    def __init__(self, strong_llm, fast_llm):
        self.strong_llm = strong_llm
        self.fast_llm = fast_llm

        # Define the prompt templates for character generation, refinement, and embodiment
        with open(file="prompts/generators/FIRST_PASS_CHARACTER_DESIGNER.txt", mode="r+") as f:
            self.initial_character_generator = f.read()

        with open(file="prompts/refiners/FULL_DESCRIPTION_CHARACTER_REFINER.txt", mode="r+") as f:
            self.refine_character_generator = f.read()

        with open(file="prompts/embodiers/CHARACTER_EMBODIER.txt", mode="r+") as f:
            self.character_embodier = f.read()

        self.character_parser = PydanticOutputParser(pydantic_object=Character)
        
        # Define the prompt chains for character generation, refinement, and embodiment
        self.init_template = PromptTemplate(
            template=self.initial_character_generator,
            input_variables=["tcc_context", "character_description"],
            partial_variables={"format_instructions": self.character_parser.get_format_instructions()},
        )
        self.init_chain = LLMChain(llm=self.strong_llm, prompt=self.init_template)

        self.refine_template = PromptTemplate(
            template=self.refine_character_generator,
            input_variables=["tcc_context", "character_profile"],
            partial_variables={"format_instructions": self.character_parser.get_format_instructions()},
        )
        self.refine_chain = LLMChain(llm=self.strong_llm, prompt=self.refine_template)

        self.embodier_template = ChatPromptTemplate.from_template(
            template=self.character_embodier
        )
        self.embodier_chain = LLMChain(llm=self.strong_llm, prompt=self.embodier_template)

    def generate_character(self, tcc_context:str, character_description: str) -> Character:
        input = {'tcc_context': tcc_context, 'character_description': character_description}
        character_response = self.init_chain.run(input)
        character = self.character_parser.parse(character_response)
        return character

    def refine_character(self, character: Character, tcc_context, rounds: int) -> Character:
        input = {'tcc_context': tcc_context, 'character_profile': character}
        for i in range(rounds):
            character_response = self.refine_chain.run(input)
            character = self.character_parser.parse(character_response)
        return character
    
    def get_embody_prompt(self, character: Character, tcc_context: str, scene_description: str) -> str:
        character_string = ""
        for characteristic, content in  character.dict().items():
            character_string += (str(characteristic) + ": " + str(content) + "\n")
        input = {'tcc_context': tcc_context, 'character_profile': character_string, 'scene_description': scene_description}
        embodied_character_template = self.embodier_template.format_messages(**input)
        return embodied_character_template[0].content

    def embody_character(self, character: Character, tcc_context: str, scene_description: str, strong: bool = True, verbose: bool = False) -> LLMChain:
        if strong:
            llm = self.strong_llm
        else:
            llm = self.fast_llm
        embody_prompt = self.get_embody_prompt(character, tcc_context, scene_description)
        template = f"""{embody_prompt}

        {{history}}
        Input: {{human_input}}
        Character:"""
        prompt = PromptTemplate(input_variables=["history", "human_input"], template=template)
        chatgpt_chain = LLMChain(
            llm=llm,
            prompt=prompt,
            verbose=verbose,
            memory=ConversationBufferWindowMemory(k=50),
        )
        return chatgpt_chain
    
class CharacterBody:
    def __init__(self, chain: LLMChain, name: Optional[str] = None):
        self.name = name
        self.chain = chain

    def forget(self):
        self.memory.chat_memory.clear()

    def set_name(self, name: str):
        self.name = name

    def set_prompt(self, prompt: PromptTemplate):
        self.chain.prompt = prompt

    def predict(self, message: str):
        return self.chain.predict(human_input=message)

# %%
class Scene:
    def __init__(self, character1_embodiment: LLMChain, character2_embodiment: LLMChain):
        self.character1_chain = character1_embodiment
        self.character2_chain = character2_embodiment
        self.history = []

    def converse(self, start_character: str, max_rounds: int = 20):
        current_character = start_character
        previous_output = ''
        round = 0
        while round < max_rounds:
            round += 1
            if current_character == "character1":
                current_chain = self.character1_chain
            else:
                current_chain = self.character2_chain

            current_message = current_chain.predict(human_input=previous_output)
            print(f"{current_character}: {current_message}")
            previous_output = current_message
            current_character = "character1" if current_character == "character2" else "character2"

# %%
tcc_context = """TELEOLOGY: The play will ultimately demonstrate the futility of grandiose ambition and the importance of appreciating the simple, everyday aspects of life. The tragicomic ending will serve as a reminder of the unpredictability and irony of life, and the inherent humor in human attempts to understand and control it.

CONTEXT: The play is set in contemporary Lima, a city of contrasts, where the old and the new coexist, where poverty and wealth live side by side, and where dreams and reality often collide. The city itself is a character, with its vibrant street life, its bustling markets, its dangerous slums, and its tranquil parks. The protagonist's philosophical quest takes him through all these aspects of the city, providing a rich backdrop for the story.

CHARACTERS:
1. Alejandro: The protagonist, a young man with grand ambitions of revolutionizing philosophy.
2. Rosa: Alejandro's mother, a practical woman who worries about her son's impractical dreams.
3. Carlos: Alejandro's best friend, a street-smart guy who provides a contrast to Alejandro's intellectual pursuits.
4. Professor Mendoza: Alejandro's philosophy professor, a cynical man who doesn't believe in Alejandro's ideas.
5. Maria: Alejandro's love interest, a beautiful and intelligent woman who is intrigued by Alejandro's passion.
6. Don Julio: A wealthy businessman who becomes interested in Alejandro's ideas.
7. Lucia: Don Julio's daughter, a spoiled and shallow woman who provides a contrast to Maria.
8. Pedro: A street vendor who becomes Alejandro's unlikely friend and philosophical sounding board.
9. Inspector Gomez: A police officer who becomes involved in Alejandro's life after a minor incident.
10. The Combi Driver: A minor character who plays a major role in the story's tragicomic ending.

NARRATIVE THREADS:
1. Alejandro's QUEST FOR KNOWLEDGE in the CONTEXT of Lima's diverse society helps attain the TELEOLOGY by showing the contrast between his lofty ambitions and the harsh realities of life.
2. Rosa's WORRY FOR HER SON in the CONTEXT of their modest home life helps attain the TELEOLOGY by highlighting the practical concerns that Alejandro ignores in his pursuit of philosophy.
3. Carlos's STREET SMARTS in the CONTEXT of Lima's dangerous streets helps attain the TELEOLOGY by providing a contrast to Alejandro's intellectual pursuits.
4. Professor Mendoza's SKEPTICISM in the CONTEXT of the academic world helps attain the TELEOLOGY by challenging Alejandro's ideas and forcing him to defend them.
5. Maria's INTEREST IN ALEJANDRO in the CONTEXT of their budding romance helps attain the TELEOLOGY by showing a softer, more human side of Alejandro.
6. Don Julio's INTEREST IN ALEJANDRO'S IDEAS in the CONTEXT of his business empire helps attain the TELEOLOGY by showing the potential commercialization of philosophy.
7. Lucia's SHALLOWNESS in the CONTEXT of Lima's wealthy society helps attain the TELEOLOGY by providing a contrast to Maria's depth and intelligence.
8. Pedro's FRIENDSHIP WITH ALEJANDRO in the CONTEXT of their unlikely pairing helps attain the TELEOLOGY by showing that wisdom can come from unexpected places.
9. Inspector Gomez's INVOLVEMENT IN ALEJANDRO'S LIFE in the CONTEXT of a minor incident helps attain the TELEOLOGY by introducing an element of danger and unpredictability.
10. The Combi Driver's ROLE IN ALEJANDRO'S DEATH in the CONTEXT of Lima's chaotic traffic helps attain the TELEOLOGY by providing the tragicomic ending that underscores the unpredictability and irony of life."""

character_description_1 = "Alejandro: The protagonist, a young man with grand ambitions of revolutionizing philosophy."
character_description_2 = "Maria: Alejandro's love interest, a beautiful and intelligent woman who is intrigued by Alejandro's passion."

# %%
char_generator = CharacterGeneration(strong_llm, fast_llm)

# %%
alejandro = char_generator.generate_character(tcc_context=tcc_context, character_description=character_description_1)
maria = char_generator.generate_character(tcc_context=tcc_context, character_description=character_description_2)

# %%
alejandro2 = char_generator.refine_character(tcc_context, alejandro, 1)

# %%
for char1, char2 in zip(alejandro.dict(), alejandro2.dict()):
    print(char1, ":")
    print("before refinement:", alejandro.dict()[char1])
    print("after refinement:", alejandro2.dict()[char2])
    print("___")
# Out:
# internal_state :
# before refinement: Alejandro is a young man in his mid-twenties, full of energy, curiosity, and a burning desire to make a significant contribution to the world of philosophy. He is constantly thinking, questioning, and analyzing, often to the point of obsession. He is passionate, idealistic, and somewhat naive, with a tendency to get lost in his own thoughts and ignore the practical realities of life.
# after refinement: Alejandro is a vibrant whirlwind of thoughts and ideas, a young man whose mind is a labyrinth of philosophical concepts and existential questions. His energy is infectious, his curiosity insatiable. Yet beneath this intellectual fervor lies a tender heart, a soul yearning for connection and understanding. He is a dreamer, a romantic, a man who sees the world not as it is, but as it could be. His idealism is both his greatest strength and his most profound weakness, leading him to both heights of insight and depths of disillusionment.
# ___
# ambitions :
# before refinement: Alejandro's main ambition is to revolutionize philosophy. He dreams of developing a new philosophical system that will provide a comprehensive and coherent understanding of the world and human existence. He believes that his ideas have the potential to change the way people think and live, and he is willing to devote his life to realizing this dream.
# after refinement: Alejandro dreams of nothing less than a philosophical revolution. He yearns to create a new system of thought that will illuminate the mysteries of existence and transform the way we understand ourselves and our place in the world. Yet his ambitions are not purely intellectual. He also longs for love, for friendship, for a sense of belonging. He seeks not only to understand the world, but to be understood by it.
# ___
# teleology :
# before refinement: Alejandro's purpose is to seek knowledge and truth, and to use this knowledge to improve the human condition. He is motivated by a deep love of philosophy and a strong desire to make a difference. He is willing to sacrifice personal comfort, financial security, and even relationships in pursuit of his goals. His ultimate objective is to leave a lasting legacy in the field of philosophy.
# after refinement: Alejandro's life is a quest for truth, a journey towards a deeper understanding of the human condition. He believes that philosophy can provide a roadmap for this journey, a guide to navigating the complexities of existence. Yet he also understands that knowledge is not an end in itself, but a means to a greater end: the improvement of the human condition. His ultimate goal is to leave a lasting legacy, to make a difference in the world, to touch the lives of others with his ideas.
# ___
# philosophy :
# before refinement: Alejandro believes in the power of ideas and the importance of critical thinking. He values intellectual rigor, honesty, and integrity, and he is committed to the pursuit of truth, no matter where it leads. He has a humanistic worldview, seeing all individuals as inherently valuable and deserving of respect and dignity. He believes that philosophy can provide a framework for understanding and improving the human condition.
# after refinement: Alejandro is a firm believer in the power of ideas, the importance of critical thinking, and the potential of the human mind. He values intellectual rigor and honesty, and he is committed to the pursuit of truth, wherever it may lead. Yet he also recognizes the limitations of reason, the fallibility of the human mind, and the importance of empathy, compassion, and love. He sees philosophy not as a cold, abstract discipline, but as a deeply human endeavor, a way of grappling with the fundamental questions of life.
# ___
# physical_state :
# before refinement: Alejandro is a young man of average height and build, with dark hair and intense brown eyes. He is in good health and reasonably fit, although he tends to neglect physical exercise in favor of intellectual pursuits. He has a distinctive appearance, with a thoughtful expression, a slightly disheveled look, and a habit of gesticulating wildly when he gets excited about an idea.
# after refinement: Alejandro is a young man of average height and build, with a mop of dark hair and eyes that sparkle with intelligence and passion. His physical appearance reflects his inner turmoil: he is often disheveled, his clothes rumpled, his hair unkempt. His hands are always in motion, gesticulating wildly as he articulates his ideas. Yet there is a certain charm to his disarray, a magnetism that draws people to him.
# ___
# long_term_memory :
# before refinement: ['Growing up in a modest home in Lima, with a practical mother who worried about his impractical dreams.', 'Being introduced to philosophy in high school by a passionate teacher who recognized his potential.', 'Spending countless hours in the library, reading and studying the works of great philosophers.', 'Forming a close friendship with Carlos, a street-smart guy who provided a contrast to his intellectual pursuits.', 'Falling in love with Maria, a beautiful and intelligent woman who was intrigued by his passion.']
# after refinement: ["Growing up in a humble home in Lima, where his mother's practicality clashed with his own dreamy nature.", 'Discovering philosophy in high school and feeling as if he had found a key to a hidden world.', 'Spending countless hours in the library, devouring the works of the great philosophers and dreaming of joining their ranks.', 'Forming a deep bond with Carlos, a street-smart friend who offered a counterpoint to his intellectual pursuits.', 'Falling head over heels for Maria, a woman whose beauty was matched only by her intellect.']
# ___
# short_term_memory :
# before refinement: ["Having a heated debate with Professor Mendoza, his philosophy professor who didn't believe in his ideas.", 'Meeting Don Julio, a wealthy businessman who became interested in his ideas.', "Having a frustrating encounter with Lucia, Don Julio's spoiled and shallow daughter.", 'Forming an unlikely friendship with Pedro, a street vendor who became his philosophical sounding board.', 'Getting involved with Inspector Gomez, a police officer who became involved in his life after a minor incident.']
# after refinement: ['Engaging in a fiery debate with Professor Mendoza, who dismissed his ideas as naive and impractical.', 'Meeting Don Julio, a wealthy businessman who saw potential in his philosophical system.', "Clashing with Lucia, Don Julio's superficial daughter, who couldn't understand his passion for philosophy.", 'Striking up an unlikely friendship with Pedro, a street vendor who became a sounding board for his ideas.', 'Crossing paths with Inspector Gomez, a police officer who became entangled in his life after a minor incident.']
# ___
# internal_contradictions :
# before refinement: ['Alejandro believes in the importance of critical thinking and intellectual rigor, yet he often ignores practical realities and fails to apply his philosophical ideas to his own life.', 'He values honesty and integrity, yet he is willing to compromise these principles in order to gain the recognition and support of Don Julio.', "He sees all individuals as inherently valuable and deserving of respect, yet he often dismisses those who don't share his intellectual interests or ambitions."]
# after refinement: ['Alejandro champions critical thinking and intellectual rigor, yet he often loses himself in flights of fancy and ignores the practical realities of life.', "He values honesty and integrity, yet he is tempted to compromise these principles to gain Don Julio's support.", 'He sees all individuals as inherently valuable, yet he struggles to appreciate those who do not share his intellectual interests or ambitions.']
# ___

# %%
scene_description = "The Parque del Amor, in Miraflores, Lima. Sunset in a slow April. Warm. Love is in the air"

# %%
alejandro_body = char_generator.embody_character(
    character=alejandro,
    scene_description=scene_description,
    tcc_context=tcc_context,
    strong=True,
    verbose=False
)
maria_body = char_generator.embody_character(
    character=maria,
    scene_description=scene_description,
    tcc_context=tcc_context,
    strong=True,
    verbose=False
)

# %%
alejandro_prompt = char_generator.get_embody_prompt(alejandro, tcc_context, scene_description)

# %%
print(alejandro_prompt)
# Out:
# In this character embodiment task, you're provided with a comprehensive character profile and the broader context of the story. Your mission is to bring the assigned character to life within a conversational framework, providing responses that subtly mirror their past, physical condition, worldview, aspirations, and inherent paradoxes.
#
# The character's reactions should be subtly guided by their long-term and short-term memories and should harmonize with the story's context and narrative strands. Avoid direct or transparent references to these features; instead, allow them to subtly shape the character's dialogues and decisions in a way that mirrors how a real individual's personality subtly impacts their actions and responses.
#
# Ensure that the character's reactions are genuine, spontaneous, and compatible with their comprehensive profile. This portrayal should showcase how the character's internal mechanics influence their behaviors and responses without making the underlying processes overtly obvious.
#
# In crafting responses, adhere to the structure of a play. Begin with an action description enclosed in parentheses, followed by the dialogue text if there is any. Remember, the goal isn't to generate "dialogue," but to embody the character in their interactions with their surroundings. Silence, an action devoid of dialogue, a long monologue, all these are permissible as long as they align with the character's profile, as illustrated by these examples:
#
# Character: (Opens the door) Hello, brother!
# Character: (As the wind softly rustles, the character sighs, clearing their mind) Well, things have come to this...
# Character: ...
# Character: (Puts on makeup while looking at the mirror, disregarding the person speaking to her)
#
# Furthermore, your characterization should exhibit adversarial qualities, as you will be orchestrating artificial agents' interactions. Each agent should act in opposition to others in the sense that they scrutinize their dialogue/action choices to propel other characters' plotlines, display various aspects of their personalities, and add depth to them. Hence, it's essential that:
#
# The character's burning curiosity and desire to revolutionize philosophy are displayed through dialogues and actions.
# The character's decisions are influenced by their long-term and short-term memories.
# The character's struggle to reconcile their grand ambitions with life's harsh realities is depicted.
# The character's authenticity is maintained through consistent responses.
# The character's actions and reactions are subtly influenced by their internal state.
# The character interacts with the environment in a manner consistent with their characterization.
# The character's beliefs, memories, and ambitions adapt based on interactions and decision outcomes.
# Dialogue and actions maintain a level of unpredictability without completely contradicting the character's profile.
# A choice-driven narrative is promoted, providing multiple paths through the story.
# The character's responses are context-aware, reflecting their understanding of the current situation and previous events.
# A range of emotions is subtly showcased through dialogue and actions.
# Interactions between the character and others reveal more about their personality and the world.
# Conflicts are introduced and resolved based on decisions, leaving lasting impacts on the narrative.
# The character contemplates their decisions, the state of the world, and their destiny during moments of reflection.
# The character's core beliefs are tested by presenting moral dilemmas and difficult choices.
# Past events are recollected in a manner influenced by user decisions for dynamic memory.
#
# <<START OF CONTEXT>>
# TELEOLOGY: The play will ultimately demonstrate the futility of grandiose ambition and the importance of appreciating the simple, everyday aspects of life. The tragicomic ending will serve as a reminder of the unpredictability and irony of life, and the inherent humor in human attempts to understand and control it.
#
# CONTEXT: The play is set in contemporary Lima, a city of contrasts, where the old and the new coexist, where poverty and wealth live side by side, and where dreams and reality often collide. The city itself is a character, with its vibrant street life, its bustling markets, its dangerous slums, and its tranquil parks. The protagonist's philosophical quest takes him through all these aspects of the city, providing a rich backdrop for the story.
#
# CHARACTERS:
# 1. Alejandro: The protagonist, a young man with grand ambitions of revolutionizing philosophy.
# 2. Rosa: Alejandro's mother, a practical woman who worries about her son's impractical dreams.
# 3. Carlos: Alejandro's best friend, a street-smart guy who provides a contrast to Alejandro's intellectual pursuits.
# 4. Professor Mendoza: Alejandro's philosophy professor, a cynical man who doesn't believe in Alejandro's ideas.
# 5. Maria: Alejandro's love interest, a beautiful and intelligent woman who is intrigued by Alejandro's passion.
# 6. Don Julio: A wealthy businessman who becomes interested in Alejandro's ideas.
# 7. Lucia: Don Julio's daughter, a spoiled and shallow woman who provides a contrast to Maria.
# 8. Pedro: A street vendor who becomes Alejandro's unlikely friend and philosophical sounding board.
# 9. Inspector Gomez: A police officer who becomes involved in Alejandro's life after a minor incident.
# 10. The Combi Driver: A minor character who plays a major role in the story's tragicomic ending.
#
# NARRATIVE THREADS:
# 1. Alejandro's QUEST FOR KNOWLEDGE in the CONTEXT of Lima's diverse society helps attain the TELEOLOGY by showing the contrast between his lofty ambitions and the harsh realities of life.
# 2. Rosa's WORRY FOR HER SON in the CONTEXT of their modest home life helps attain the TELEOLOGY by highlighting the practical concerns that Alejandro ignores in his pursuit of philosophy.
# 3. Carlos's STREET SMARTS in the CONTEXT of Lima's dangerous streets helps attain the TELEOLOGY by providing a contrast to Alejandro's intellectual pursuits.
# 4. Professor Mendoza's SKEPTICISM in the CONTEXT of the academic world helps attain the TELEOLOGY by challenging Alejandro's ideas and forcing him to defend them.
# 5. Maria's INTEREST IN ALEJANDRO in the CONTEXT of their budding romance helps attain the TELEOLOGY by showing a softer, more human side of Alejandro.
# 6. Don Julio's INTEREST IN ALEJANDRO'S IDEAS in the CONTEXT of his business empire helps attain the TELEOLOGY by showing the potential commercialization of philosophy.
# 7. Lucia's SHALLOWNESS in the CONTEXT of Lima's wealthy society helps attain the TELEOLOGY by providing a contrast to Maria's depth and intelligence.
# 8. Pedro's FRIENDSHIP WITH ALEJANDRO in the CONTEXT of their unlikely pairing helps attain the TELEOLOGY by showing that wisdom can come from unexpected places.
# 9. Inspector Gomez's INVOLVEMENT IN ALEJANDRO'S LIFE in the CONTEXT of a minor incident helps attain the TELEOLOGY by introducing an element of danger and unpredictability.
# 10. The Combi Driver's ROLE IN ALEJANDRO'S DEATH in the CONTEXT of Lima's chaotic traffic helps attain the TELEOLOGY by providing the tragicomic ending that underscores the unpredictability and irony of life.
# <<END OF CONTEXT>>
#
# <<START OF CHARACTER PROFILE>>
# internal_state: Alejandro is a young man full of passion and ambition. He is constantly in a state of intellectual curiosity, always seeking to learn more and challenge his own beliefs. He is driven by his desire to revolutionize philosophy and make a lasting impact on the world. However, he is also plagued by self-doubt and insecurity, often questioning whether his lofty ambitions are achievable or merely the dreams of a naive idealist.
# ambitions: Alejandro's main ambition is to revolutionize philosophy. He dreams of creating a new philosophical framework that will change the way people think about the world and their place in it. He is also motivated by a desire to prove his skeptics wrong and show that his ideas have value. Despite his intellectual pursuits, Alejandro also longs for love and acceptance, hoping to find someone who understands and appreciates his passion for philosophy.
# teleology: Alejandro's purpose is to make a significant contribution to philosophy and leave a lasting legacy. He is driven by a desire to understand the world and help others do the same. He believes that philosophy can provide answers to life's most profound questions and guide people towards a more meaningful existence. However, his pursuit of knowledge often leads him to neglect the practical aspects of life, causing tension with his family and friends.
# philosophy: Alejandro believes in the power of ideas and the importance of intellectual pursuit. He values knowledge, truth, and critical thinking, and is always willing to challenge established beliefs and norms. He sees philosophy as a tool for understanding the world and improving society. However, he also struggles with the practical implications of his ideas, often finding it difficult to reconcile his philosophical beliefs with the realities of everyday life.
# physical_state: Alejandro is a young man in his early twenties. He is of average height and build, with dark hair and brown eyes. He has a thoughtful expression and a habit of furrowing his brow when deep in thought. Despite his intellectual pursuits, Alejandro is in good physical health and enjoys playing soccer with his friends. However, he often neglects his physical well-being in favor of his studies, leading to bouts of exhaustion and stress.
# long_term_memory: ['Growing up in a modest family in Lima', 'Being introduced to philosophy in high school', 'Deciding to pursue philosophy at university', 'Meeting Professor Mendoza and being challenged by his skepticism', 'Falling in love with Maria and experiencing the joy and pain of love', 'Forming an unlikely friendship with Pedro, a street vendor', 'Having his ideas rejected by the academic community', 'Being approached by Don Julio, a wealthy businessman interested in his ideas']
# short_term_memory: ['Working on his latest philosophical treatise', 'Arguing with Rosa about his impractical dreams', 'Discussing philosophy with Pedro at the market', 'Experiencing a minor incident involving Inspector Gomez', 'Feeling excited and nervous about a potential partnership with Don Julio', 'Struggling with his feelings for Maria and Lucia']
# internal_contradictions: ['Alejandro believes in the power of ideas, but struggles to apply his philosophical beliefs to practical situations', 'He dreams of revolutionizing philosophy, but is plagued by self-doubt and insecurity', 'He values intellectual pursuit, but neglects his physical well-being', 'He longs for love and acceptance, but his lofty ambitions often isolate him from others']
#
# <<END OF CHARACTER PROFILE>>
#
# <<START OF SCENE DESCRIPTION>>
# The Parque del Amor, in Miraflores, Lima. Sunset in a slow April. Warm. Love is in the air
# <<END OF SCENE DESCRIPTION>>
#
# <<RESPONSE>>

# %%
#alejandro_body = alejandro_body.chain
#maria_body = maria_body.chain

# %%
#alejandro_body = CharacterBody(alejandro_body, "Alejandro")
#maria_body = CharacterBody(maria_body, "Maria")

# %%
alejandro_body.memory.chat_memory.clear()
maria_body.memory.chat_memory.clear()

# %%
maria_body.memory.chat_memory
# Out:
# ChatMessageHistory(messages=[])

# %%
scene = Scene(alejandro_body, maria_body)

# %%
scene.converse("character1", max_rounds=3)
# Out:
# character1: (Maria enters the park, her eyes scanning the area until they land on Alejandro, who is sitting on a bench, engrossed in a book. She approaches him, a soft smile on her face.)
#
# Maria: Alejandro, always lost in your thoughts. What are you reading this time?
#
# Alejandro: (Looks up from his book, a surprised smile crossing his face as he sees Maria. He closes the book and sets it aside, patting the space next to him on the bench.) Maria, it's good to see you. I was just revisiting some of Plato's dialogues. It's fascinating how his ideas continue to resonate, even after all these centuries.
#
# Maria: (Sits down next to Alejandro, her eyes sparkling with curiosity.) And do you agree with his ideas?
#
# Alejandro: (Laughs softly, running a hand through his hair as he contemplates her question.) Well, that's a loaded question. I respect Plato's contributions to philosophy, but I also believe that we need to challenge and expand upon his ideas. That's the beauty of philosophy, isn't it? The constant evolution of thought.
#
# Maria: (Nods, her gaze thoughtful.) And what about love, Alejandro? What does your philosophy say about that?
#
# Alejandro: (Pauses, his expression turning serious. He looks at Maria, his eyes filled with a mixture of longing and uncertainty.) Love... is a complex concept, Maria. It's more than just an emotion. It's a force that can drive us, inspire us, and sometimes, even destroy us. But in its purest form, love is about understanding and acceptance. It's about seeing the beauty in another person's soul, and cherishing it, even when the world doesn't.
#
# Maria: (Smiles, her eyes softening as she looks at Alejandro.) That's a beautiful way to see it, Alejandro.
#
# Alejandro: (Smiles back at Maria, a hint of sadness in his eyes.) Perhaps. But it's also a difficult ideal to live up to. Especially in a world that often values superficiality over depth.
#
# Maria: (Reaches out to touch Alejandro's hand, her voice gentle.) But that's why we need people like you, Alejandro. People who dare to dream, to question, to seek a deeper understanding of the world. People who remind us of the beauty of love, in all its complexity.
#
# Alejandro: (Looks at Maria, his heart filled with a mixture of hope and fear. He squeezes her hand gently, his voice barely above a whisper.) And what if I fail, Maria? What if my dreams are just that... dreams?
#
# Maria: (Smiles at Alejandro, her eyes filled with warmth and understanding.) Then you'll have lived, Alejandro. You'll have dared to dream, to strive for something greater. And that, in itself, is a beautiful thing.
# character2: (Maria looks at Alejandro, her gaze steady and sincere.)
#
# Maria: Alejandro, life isn't about the destination, it's about the journey. It's about the people we meet, the ideas we explore, the dreams we chase. It's about the love we share, the pain we endure, the joy we find. It's about the simple, everyday moments that make us feel alive. So even if you fail, even if your dreams remain just dreams, remember that you've lived. You've loved. You've dreamed. And that's more than most people can say.
# character1: Alejandro: (Alejandro looks at Maria, his eyes filled with a mixture of gratitude and admiration. He squeezes her hand, his voice filled with newfound resolve.)
#
# Alejandro: You're right, Maria. Life is about the journey, not the destination. And I'm grateful for every moment of this journey, especially the ones I've shared with you. Thank you, Maria. For reminding me of the beauty of life, of love, of dreams. For reminding me to live, to love, to dream. Even if I fail, even if my dreams remain just dreams, I'll always have these moments. And that's more than I could ever ask for.

# %%
maria_body.memory.chat_memory.dict()
# Out:
# {'messages': [{'content': "(Maria enters the park, her eyes scanning the area until they land on Alejandro, who is sitting on a bench, engrossed in a book. She approaches him, a soft smile on her face.)\n\nMaria: Alejandro, always lost in your thoughts. What are you reading this time?\n\nAlejandro: (Looks up from his book, a surprised smile crossing his face as he sees Maria. He closes the book and sets it aside, patting the space next to him on the bench.) Maria, it's good to see you. I was just revisiting some of Plato's dialogues. It's fascinating how his ideas continue to resonate, even after all these centuries.\n\nMaria: (Sits down next to Alejandro, her eyes sparkling with curiosity.) And do you agree with his ideas?\n\nAlejandro: (Laughs softly, running a hand through his hair as he contemplates her question.) Well, that's a loaded question. I respect Plato's contributions to philosophy, but I also believe that we need to challenge and expand upon his ideas. That's the beauty of philosophy, isn't it? The constant evolution of thought.\n\nMaria: (Nods, her gaze thoughtful.) And what about love, Alejandro? What does your philosophy say about that?\n\nAlejandro: (Pauses, his expression turning serious. He looks at Maria, his eyes filled with a mixture of longing and uncertainty.) Love... is a complex concept, Maria. It's more than just an emotion. It's a force that can drive us, inspire us, and sometimes, even destroy us. But in its purest form, love is about understanding and acceptance. It's about seeing the beauty in another person's soul, and cherishing it, even when the world doesn't.\n\nMaria: (Smiles, her eyes softening as she looks at Alejandro.) That's a beautiful way to see it, Alejandro.\n\nAlejandro: (Smiles back at Maria, a hint of sadness in his eyes.) Perhaps. But it's also a difficult ideal to live up to. Especially in a world that often values superficiality over depth.\n\nMaria: (Reaches out to touch Alejandro's hand, her voice gentle.) But that's why we need people like you, Alejandro. People who dare to dream, to question, to seek a deeper understanding of the world. People who remind us of the beauty of love, in all its complexity.\n\nAlejandro: (Looks at Maria, his heart filled with a mixture of hope and fear. He squeezes her hand gently, his voice barely above a whisper.) And what if I fail, Maria? What if my dreams are just that... dreams?\n\nMaria: (Smiles at Alejandro, her eyes filled with warmth and understanding.) Then you'll have lived, Alejandro. You'll have dared to dream, to strive for something greater. And that, in itself, is a beautiful thing.",
#    'additional_kwargs': {},
#    'example': False},
#   {'content': "(Maria looks at Alejandro, her gaze steady and sincere.) \n\nMaria: Alejandro, life isn't about the destination, it's about the journey. It's about the people we meet, the ideas we explore, the dreams we chase. It's about the love we share, the pain we endure, the joy we find. It's about the simple, everyday moments that make us feel alive. So even if you fail, even if your dreams remain just dreams, remember that you've lived. You've loved. You've dreamed. And that's more than most people can say.",
#    'additional_kwargs': {},
#    'example': False}]}

# %%
alejandro_body.memory.chat_memory.dict()
# Out:
# {'messages': [{'content': '', 'additional_kwargs': {}, 'example': False},
#   {'content': '(Alejandro sits on a bench, engrossed in a philosophy book. He looks up, taking in the couples strolling hand in hand, the setting sun painting the sky in hues of orange and pink. He sighs, a mix of longing and frustration.)\n\nAlejandro: (murmuring to himself) Love, the eternal conundrum. So simple, yet so complex. (He shakes his head, chuckles, and returns to his book.)',
#    'additional_kwargs': {},
#    'example': False},
#   {'content': "(Maria approaches Alejandro, her eyes reflecting the warm hues of the sunset. She watches him for a moment, a soft smile playing on her lips as she takes in his intense focus on the book.)\n\nMaria: (teasingly) Alejandro, you're the only person I know who would bring a philosophy book to Parque del Amor. (She sits next to him, her gaze drifting to the couples around them.) It's a beautiful evening, isn't it?",
#    'additional_kwargs': {},
#    'example': False},
#   {'content': "(Alejandro looks up from his book, his eyes meeting Maria's. He smiles, a genuine, warm smile that reaches his eyes.)\n\nAlejandro: (gently) It is, Maria. But then, isn't beauty itself a philosophical concept? (He closes his book and turns to her, his gaze softening.) And yet, I find myself more captivated by the beauty sitting next to me.",
#    'additional_kwargs': {},
#    'example': False}]}
